# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def create_binary_tree(root):
    data = int(input("Enter Data\n"))
    if data == -1:
        return None
    root = Node(data)
    print("Enter Data left to ", data)
    root.left = create_binary_tree(root.left)
    print("Enter Data right to ", data)
    root.right = create_binary_tree(root.right)
    return root

def inorder_traversal(root):
    if not root:
        return
    inorder_traversal(root.left)
    print(root.data, end=" ")
    inorder_traversal(root.right)

def preorder_traversal(root):
    if not root:
        return
    print(root.data, end=" ")
    preorder_traversal(root.left)
    preorder_traversal(root.right)

def postorder_traversal(root):
    if not root:
        return
    postorder_traversal(root.left)
    postorder_traversal(root.right)
    print(root.data, end=" ")

root = None
root = create_binary_tree(root)
print("PreOrder Traversal")
preorder_traversal(root)
print("\nInOrder Traversal")
inorder_traversal(root)
print("\nPostOrder Traversal")
postorder_traversal(root)
# Out:
# Enter Data
# 1
# Enter Data left to  1
# Enter Data
# 2
# Enter Data left to  2
# Enter Data
# 4
# Enter Data left to  4
# Enter Data
# -1
# Enter Data right to  4
# Enter Data
# -1
# Enter Data right to  2
# Enter Data
# 5
# Enter Data left to  5
# Enter Data
# -1
# Enter Data right to  5
# Enter Data
# -1
# Enter Data right to  1
# Enter Data
# 3
# Enter Data left to  3
# Enter Data
# 6
# Enter Data left to  6
# Enter Data
# -1
# Enter Data right to  6
# Enter Data
# -1
# Enter Data right to  3
# Enter Data
# 7
# Enter Data left to  7
# Enter Data
# -1
# Enter Data right to  7
# Enter Data
# -1
# PreOrder Traversal
# 1 2 4 5 3 6 7
# InOrder Traversal
# 4 2 5 1 6 3 7
# PostOrder Traversal
# 4 5 2 6 7 3 1
